# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy import stats
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key



city_name = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

index = 1
count = 0

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    try:
        City_data = (requests.get(url + '&q=' + city)).json()
        city_name.append(City_data['name'])
        Cloudiness.append(City_data['clouds']['all'])
        Country.append(City_data['sys']['country'])
        Date.append(City_data['dt'])
        Humidity.append(City_data['main']['humidity'])
        Lat.append(City_data['coord']['lat'])
        Lng.append(City_data['coord']['lon'])
        Max_Temp.append(City_data['main']['temp_max'])
        Wind_Speed.append(City_data['wind']['speed'])
        print(f"Processing Record {index} of Set 1 | {city}")
        index += 1
        count += 1
    
    except:
        print(f'Missing data in city number {index} | Skipping {city}')
        index += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nuuk
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | urumqi
# Processing Record 12 of Set 1 | novyy urengoy
# Processing Record 13 of Set 1 | rorvik
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | marzuq
# Processing Record 17 of Set 1 | sarkand
# Processing Record 18 of Set 1 | okhotsk
# Processing Record 19 of Set 1 | itoman
# Missing data in city number 20 | Skipping tabukiniberu
# Processing Record 21 of Set 1 | krasnoselkup
# Processing Record 22 of Set 1 | birjand
# Processing Record 23 of Set 1 | sabya
# Processing Record 24 of Set 1 | pilar
# Processing Record 25 of Set 1 | alofi
# Processing Record 26 of Set 1 | makakilo city
# Processing Record 27 of Set 1 | bollnas
# Processing Record 28 of Set 1 | astaneh-ye ashrafiyeh
# Processing Record 29 of Set 1 | sergeyevka
# Processing Record 30 of Set 1 | puri
# Processing Record 31 of Set 1 | atar
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | te anau
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | suhbaatar
# Processing Record 38 of Set 1 | waitati
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | bluff
# Missing data in city number 42 | Skipping taolanaro
# Missing data in city number 43 | Skipping kamenskoye
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | bruck an der leitha
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | airai
# Missing data in city number 48 | Skipping illoqqortoormiut
# Processing Record 49 of Set 1 | luxor
# Processing Record 50 of Set 1 | hohhot
# Processing Record 51 of Set 1 | haines city
# Processing Record 52 of Set 1 | bilma
# Missing data in city number 53 | Skipping marcona
# Processing Record 54 of Set 1 | barrow
# Processing Record 55 of Set 1 | kruisfontein
# Processing Record 56 of Set 1 | kalemie
# Processing Record 57 of Set 1 | kodinsk
# Processing Record 58 of Set 1 | butaritari
# Processing Record 59 of Set 1 | samarai
# Processing Record 60 of Set 1 | new norfolk
# Processing Record 61 of Set 1 | los llanos de aridane
# Processing Record 62 of Set 1 | ancud
# Processing Record 63 of Set 1 | east london
# Missing data in city number 64 | Skipping nizhneyansk
# Processing Record 65 of Set 1 | avarua
# Processing Record 66 of Set 1 | teseney
# Processing Record 67 of Set 1 | sitka
# Processing Record 68 of Set 1 | dinajpur
# Processing Record 69 of Set 1 | wodonga
# Processing Record 70 of Set 1 | qaanaaq
# Processing Record 349 of Set 1 | berezovyy
# Processing Record 350 of Set 1 | dunedin
# Processing Record 351 of Set 1 | metro
# Processing Record 352 of Set 1 | cortez
# Processing Record 353 of Set 1 | maku
# Processing Record 354 of Set 1 | pervomayskoye
# Processing Record 355 of Set 1 | castelo branco
# Processing Record 356 of Set 1 | arman
# Processing Record 357 of Set 1 | nouadhibou
# Processing Record 358 of Set 1 | tigzirt
# Processing Record 359 of Set 1 | tilichiki
# Processing Record 360 of Set 1 | bella union
# Processing Record 361 of Set 1 | babushkin
# Missing data in city number 362 | Skipping bolshiye uki
# Processing Record 363 of Set 1 | puerto del rosario
# Processing Record 364 of Set 1 | kaniama
# Processing Record 365 of Set 1 | show low
# Processing Record 366 of Set 1 | beaverlodge
# Processing Record 367 of Set 1 | lukovetskiy
# Processing Record 368 of Set 1 | ambilobe
# Processing Record 369 of Set 1 | paysandu
# Processing Record 370 of Set 1 | zyryanka
# Processing Record 371 of Set 1 | bidor
# Processing Record 372 of Set 1 | hervey bay
# Processing Record 373 of Set 1 | cururupu
# Processing Record 374 of Set 1 | ribeira grande
# Processing Record 375 of Set 1 | los andes
# Processing Record 376 of Set 1 | taber
# Processing Record 377 of Set 1 | moree
# Processing Record 378 of Set 1 | ishinomaki
# Processing Record 379 of Set 1 | visby
# Processing Record 380 of Set 1 | orlik
# Processing Record 381 of Set 1 | ambon
# Processing Record 382 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 383 of Set 1 | hay river
# Processing Record 384 of Set 1 | benidorm
# Processing Record 385 of Set 1 | litovko
# Processing Record 386 of Set 1 | batemans bay
# Processing Record 387 of Set 1 | umm kaddadah
# Processing Record 388 of Set 1 | limbang
# Processing Record 389 of Set 1 | ocos
# Processing Record 390 of Set 1 | axim
# Missing data in city number 391 | Skipping karkaralinsk
# Processing Record 392 of Set 1 | shelburne
# Processing Record 393 of Set 1 | san marcos
# Processing Record 394 of Set 1 | pemba
# Processing Record 395 of Set 1 | puksoozero
# Processing Record 396 of Set 1 | adrar
# Processing Record 397 of Set 1 | onesti
# Processing Record 398 of Set 1 | tautira
# Processing Record 399 of Set 1 | bundaberg
# Processing Record 400 of Set 1 | batagay-alyta
# Processing Record 401 of Set 1 | mareeba
# Processing Record 402 of Set 1 | ahipara
# Processing Record 403 of Set 1 | beringovskiy
# Processing Record 404 of Set 1 | jinsha
# Processing Record 405 of Set 1 | ulverstone
# Missing data in city number 406 | Skipping mys shmidta
# Processing Record 407 of Set 1 | sept-iles
# Processing Record 408 of Set 1 | zambezi
# Processing Record 409 of Set 1 | valdivia
# Processing Record 410 of Set 1 | biak
# Processing Record 411 of Set 1 | yarada
# Processing Record 412 of Set 1 | dillon
# Processing Record 413 of Set 1 | sakakah
# Processing Record 414 of Set 1 | ouadda
# Processing Record 415 of Set 1 | sibolga
# Processing Record 416 of Set 1 | edgewater
# Processing Record 417 of Set 1 | kampot
# Missing data in city number 418 | Skipping cockburn harbour
# Processing Record 419 of Set 1 | acopiara
# Processing Record 420 of Set 1 | margate
# Processing Record 421 of Set 1 | san jose
# Processing Record 422 of Set 1 | jagdalpur
# Processing Record 423 of Set 1 | lakes entrance
# Processing Record 424 of Set 1 | saint-augustin
# Processing Record 425 of Set 1 | yeppoon
# Processing Record 426 of Set 1 | aksarayskiy
# Processing Record 427 of Set 1 | uray
# Processing Record 428 of Set 1 | zhezkazgan
# Processing Record 429 of Set 1 | cabo san lucas
# Processing Record 430 of Set 1 | takoradi
# Processing Record 431 of Set 1 | pisco
# Missing data in city number 432 | Skipping tabiauea
# Processing Record 433 of Set 1 | anadyr
# Missing data in city number 434 | Skipping jiroft
# Processing Record 435 of Set 1 | hailar
# Processing Record 436 of Set 1 | duku
# Processing Record 437 of Set 1 | saint george
# Processing Record 438 of Set 1 | olafsvik
# Processing Record 439 of Set 1 | honningsvag
# Processing Record 440 of Set 1 | kassala
# Processing Record 441 of Set 1 | solhan
# Processing Record 442 of Set 1 | klaksvik
# Processing Record 443 of Set 1 | galveston
# Processing Record 444 of Set 1 | san cristobal
# Processing Record 445 of Set 1 | scottsboro
# Processing Record 446 of Set 1 | pucallpa
# Processing Record 447 of Set 1 | antofagasta
# Processing Record 448 of Set 1 | necochea
# Processing Record 449 of Set 1 | kloulklubed
# Processing Record 450 of Set 1 | jalu
# Processing Record 451 of Set 1 | daru
# Processing Record 452 of Set 1 | black river
# Processing Record 453 of Set 1 | nuristan
# Processing Record 454 of Set 1 | buncrana
# Processing Record 455 of Set 1 | magdalena
# Processing Record 456 of Set 1 | yamada
# Processing Record 457 of Set 1 | saint-pierre
# Processing Record 458 of Set 1 | flinders
# Processing Record 459 of Set 1 | aripuana
# Processing Record 460 of Set 1 | deming
# Processing Record 461 of Set 1 | puerto narino
# Processing Record 462 of Set 1 | burnie
# Missing data in city number 463 | Skipping grand river south east
# Processing Record 464 of Set 1 | fortuna
# Processing Record 465 of Set 1 | hami
# Processing Record 466 of Set 1 | nabire
# Missing data in city number 467 | Skipping warqla
# Processing Record 468 of Set 1 | stantsionno-oyashinskiy
# Processing Record 469 of Set 1 | sangueya
# Processing Record 470 of Set 1 | bairiki
# Processing Record 471 of Set 1 | diu
# Processing Record 472 of Set 1 | bayji
# Processing Record 473 of Set 1 | sambava
# Processing Record 474 of Set 1 | thunder bay
# Missing data in city number 475 | Skipping umzimvubu
# Processing Record 476 of Set 1 | valentin gomez farias
# Processing Record 477 of Set 1 | longyearbyen
# Processing Record 478 of Set 1 | port macquarie
# Processing Record 479 of Set 1 | isoka
# Processing Record 480 of Set 1 | gamba
# Processing Record 481 of Set 1 | kahului
# Processing Record 482 of Set 1 | christchurch
# Processing Record 483 of Set 1 | termiz
# Processing Record 484 of Set 1 | camacha
# Processing Record 485 of Set 1 | bar harbor
# Processing Record 486 of Set 1 | naze
# Processing Record 487 of Set 1 | xining
# Processing Record 488 of Set 1 | talnakh
# Processing Record 489 of Set 1 | laminusa
# Processing Record 490 of Set 1 | beitbridge
# Processing Record 491 of Set 1 | athabasca
# Processing Record 492 of Set 1 | pandaria
# Processing Record 493 of Set 1 | otane
# Processing Record 494 of Set 1 | bahia blanca
# Missing data in city number 495 | Skipping louisbourg
# Processing Record 496 of Set 1 | saurimo
# Processing Record 497 of Set 1 | kapit
# Processing Record 498 of Set 1 | cozumel
# Processing Record 499 of Set 1 | warri
# Processing Record 500 of Set 1 | zhigansk
# Processing Record 501 of Set 1 | aginskoye
# Missing data in city number 502 | Skipping dinsor
# Processing Record 503 of Set 1 | mbigou
# Processing Record 504 of Set 1 | lagoa
# Processing Record 505 of Set 1 | shibganj
# Processing Record 506 of Set 1 | wanaka
# Processing Record 507 of Set 1 | casper
# Processing Record 508 of Set 1 | isangel
# Processing Record 509 of Set 1 | shingu
# Processing Record 510 of Set 1 | dicabisagan
# Processing Record 511 of Set 1 | lake cowichan
# Processing Record 512 of Set 1 | corrales
# Processing Record 513 of Set 1 | san policarpo
# Processing Record 514 of Set 1 | nova olimpia
# Processing Record 515 of Set 1 | meulaboh
# Processing Record 516 of Set 1 | carnot
# Processing Record 517 of Set 1 | pangoa
# Processing Record 518 of Set 1 | tupi paulista
# Processing Record 519 of Set 1 | namibe
# Processing Record 520 of Set 1 | yar-sale
# Processing Record 521 of Set 1 | harer
# Processing Record 522 of Set 1 | kayerkan
# Processing Record 523 of Set 1 | mirnyy
# Processing Record 524 of Set 1 | tonantins
# Processing Record 525 of Set 1 | mount gambier
# Processing Record 526 of Set 1 | southbridge
# Processing Record 527 of Set 1 | komsomolskiy
# Processing Record 528 of Set 1 | moron
# Processing Record 529 of Set 1 | ak-dovurak
# Processing Record 530 of Set 1 | krasnotorka
# Processing Record 531 of Set 1 | rurrenabaque
# Processing Record 532 of Set 1 | floro
# Processing Record 533 of Set 1 | churapcha
# Processing Record 534 of Set 1 | comodoro rivadavia
# Processing Record 535 of Set 1 | taltal
# Processing Record 536 of Set 1 | kavieng
# Processing Record 537 of Set 1 | ust-tsilma
# Processing Record 538 of Set 1 | uniao
# Processing Record 539 of Set 1 | bodden town
# Processing Record 540 of Set 1 | karratha
# Processing Record 541 of Set 1 | willowmore
# Processing Record 542 of Set 1 | kismayo
# Processing Record 543 of Set 1 | oistins
# Processing Record 544 of Set 1 | springdale
# Processing Record 545 of Set 1 | ust-nera
# Processing Record 546 of Set 1 | codrington
# Processing Record 547 of Set 1 | ukiah
# Processing Record 548 of Set 1 | shumikha
# Processing Record 549 of Set 1 | concordia
# Processing Record 550 of Set 1 | barra
# Processing Record 551 of Set 1 | sinnamary
# Missing data in city number 552 | Skipping meyungs
# Missing data in city number 553 | Skipping sorvag
# Processing Record 554 of Set 1 | northview
# Missing data in city number 555 | Skipping samusu
# Processing Record 556 of Set 1 | mount isa
# Missing data in city number 557 | Skipping ust-kamchatsk
# Processing Record 558 of Set 1 | high level
# Processing Record 559 of Set 1 | ulaangom
# Processing Record 560 of Set 1 | pompeu
# Processing Record 561 of Set 1 | nishihara
# Processing Record 562 of Set 1 | wahiawa
# Processing Record 563 of Set 1 | zaysan
# Processing Record 564 of Set 1 | poum
# Processing Record 565 of Set 1 | kaseda
# Processing Record 566 of Set 1 | erdemli
# Processing Record 567 of Set 1 | westport
# Missing data in city number 568 | Skipping tapaua
# Processing Record 569 of Set 1 | sur
# Missing data in city number 570 | Skipping bolungarvik
# Processing Record 571 of Set 1 | kieta
# Processing Record 572 of Set 1 | san ramon de la nueva oran
# Processing Record 573 of Set 1 | sakaraha
# Processing Record 574 of Set 1 | kalabo
# Processing Record 575 of Set 1 | viedma
# Processing Record 576 of Set 1 | tahe
# Missing data in city number 577 | Skipping wulanhaote
# Processing Record 578 of Set 1 | korla
# Missing data in city number 579 | Skipping blonduos
# Processing Record 580 of Set 1 | chernyshevskiy
# Missing data in city number 581 | Skipping chatsu
# Processing Record 582 of Set 1 | pangai
# Missing data in city number 583 | Skipping bargal
# Processing Record 584 of Set 1 | guadalajara
# Processing Record 585 of Set 1 | deputatskiy
# Processing Record 586 of Set 1 | pangkalanbuun
# Processing Record 587 of Set 1 | phalodi
# Processing Record 588 of Set 1 | narasannapeta
# Processing Record 589 of Set 1 | neiafu
# Processing Record 590 of Set 1 | murgab
# Processing Record 591 of Set 1 | guerande
# Processing Record 592 of Set 1 | emerald
# Processing Record 593 of Set 1 | jesup
# Processing Record 594 of Set 1 | matara
# Processing Record 595 of Set 1 | maumere
# Processing Record 596 of Set 1 | acandi
# Processing Record 597 of Set 1 | hambantota
# Processing Record 598 of Set 1 | lahij
# Processing Record 599 of Set 1 | gazanjyk
# Processing Record 600 of Set 1 | altagracia de orituco

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
length_City = {
     'City': len(city_name),
     'Cloudiness': len(Cloudiness),
     'Country': len(Country),
     'Date': len(Date),
     'Humidity': len(Humidity),
     'Lat': len(Lat),
     'Lng': len(Lng),
     'Max Temp': len(Max_Temp),
     'Wind Speed': len(Wind_Speed)
 }

length_City
# Out:
# {'City': 551,
#  'Cloudiness': 551,
#  'Country': 551,
#  'Date': 551,
#  'Humidity': 551,
#  'Lat': 551,
#  'Lng': 551,
#  'Max Temp': 551,
#  'Wind Speed': 551}

# %%
Weather_df = pd.DataFrame({
                        'City': city_name,
                        'Cloudiness': Cloudiness,
                        'Country': Country,
                        'Date': Date,
                        'Humidity': Humidity,
                        'Lat': Lat,
                        'Lng': Lng,
                        'Max Temp': Max_Temp,
                        'Wind Speed': Wind_Speed
                        })

pd.DataFrame.to_csv(Weather_df, 'city_data.csv')
Weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Nuuk         100      GL  1579142624        72  64.18  -51.72
# 1      Hermanus           0      ZA  1579142624        86 -34.42   19.23
# 2       Ushuaia          75      AR  1579142399        86 -54.80  -68.30
# 3       Mataura           0      NZ  1579142625        47 -46.19  168.86
# 4  Punta Arenas          20      CL  1579142626        75 -53.15  -70.92
#
#    Max Temp  Wind Speed
# 0     15.80       16.11
# 1     75.00        7.00
# 2     41.00       38.03
# 3     76.53        1.90
# 4     42.80       17.22

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Max Temp']
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Max Temperature ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Humidity'] 
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Humidity ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Cloudiness']
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Cloudiness ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Wind Speed']
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Wind Speed ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def regression(X_value, Y_value, X_lable, Y_lable):
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(X_value, Y_value)
    regress_value = X_value * slope + intercept
    
    line_eq = f" y= {round(slope,2)}x + {round(intercept,2)}"
    
    plt.annotate(line_eq, (20, 15), fontsize=15, color='red')
    plt.scatter(X_value, Y_value, marker='o', color='blue')
    plt.title(f"City Latitude vs. Wind Speed ({weather_dt})")
    plt.grid()
    plt.xlabel(X_lable)
    plt.ylabel(Y_lable)
    print(f"The r-squared is: {rvalue}")

    plt.plot(X_value, regress_value, 'r-')
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_df = Weather_df.loc[Weather_df['Lng']>=0]
Southern_df = Weather_df.loc[Weather_df['Lng']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = Northern_df['Lat']
y_value = Northern_df['Max Temp']
X_lable = 'Latitude'
Y_lable = 'Max Temp'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.815065953143161

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = Southern_df['Max Temp']
y_value = Southern_df['Lat']
X_lable = 'Latitude'
Y_lable = 'Max Temp'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.6882265267470087

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = Northern_df['Max Temp']
y_value = Northern_df['Lat']
X_lable = 'Latitude'
Y_lable = 'Max Temp'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.815065953143161

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = Southern_df['Lat']
y_value = Southern_df['Humidity']
X_lable = 'Latitude'
Y_lable = 'Humidity'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.03875753823198238

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = Northern_df['Lat']
y_value = Northern_df['Cloudiness']
X_lable = 'Latitude'
Y_lable = 'Cloudiness'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.29085386989961426

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = Southern_df['Lat']
y_value = Southern_df['Cloudiness']
X_lable = 'Latitude'
Y_lable = 'Cloudiness'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.17247317962170883

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = Northern_df['Lat']
y_value = Northern_df['Wind Speed']
X_lable = 'Latitude'
Y_lable = 'Wind Speed'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.0024562922306882924

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = Southern_df['Lat']
y_value = Southern_df['Wind Speed']
X_lable = 'Latitude'
Y_lable = 'Wind Speed'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.08179193868666713
