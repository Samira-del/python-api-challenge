# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy import stats
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key



city_name = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

index = 1
count = 0

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    try:
        City_data = (requests.get(url + '&q=' + city)).json()
        city_name.append(City_data['name'])
        Cloudiness.append(City_data['clouds']['all'])
        Country.append(City_data['sys']['country'])
        Date.append(City_data['dt'])
        Humidity.append(City_data['main']['humidity'])
        Lat.append(City_data['coord']['lat'])
        Lng.append(City_data['coord']['lon'])
        Max_Temp.append(City_data['main']['temp_max'])
        Wind_Speed.append(City_data['wind']['speed'])
        print(f"Processing Record {index} of Set 1 | {city}")
        index += 1
        count += 1
    
    except:
        print(f'Missing data in city number {index} | Skipping {city}')
        index += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Missing data in city number 1 | Skipping nizhneyansk
# Processing Record 2 of Set 1 | quatre cocos
# Processing Record 3 of Set 1 | half moon bay
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | kovur
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | vestmanna
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | asau
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | ushuaia
# Missing data in city number 15 | Skipping samusu
# Processing Record 16 of Set 1 | cabo san lucas
# Missing data in city number 17 | Skipping illoqqortoormiut
# Processing Record 18 of Set 1 | clyde river
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | caxito
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | beberibe
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | baiyin
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | kulhudhuffushi
# Processing Record 31 of Set 1 | pushkino
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | yulara
# Processing Record 34 of Set 1 | morogoro
# Processing Record 35 of Set 1 | pelym
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | pacific grove
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | ereymentau
# Missing data in city number 40 | Skipping taolanaro
# Processing Record 41 of Set 1 | pishva
# Processing Record 42 of Set 1 | valparaiso
# Processing Record 43 of Set 1 | comodoro rivadavia
# Processing Record 44 of Set 1 | zhigansk
# Processing Record 45 of Set 1 | banning
# Processing Record 46 of Set 1 | cape town
# Missing data in city number 47 | Skipping narsaq
# Processing Record 48 of Set 1 | saint-joseph
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | pundaguitan
# Processing Record 51 of Set 1 | barcelos
# Processing Record 52 of Set 1 | hendek
# Processing Record 53 of Set 1 | albany
# Missing data in city number 54 | Skipping urdzhar
# Processing Record 55 of Set 1 | pevek
# Processing Record 56 of Set 1 | provideniya
# Processing Record 57 of Set 1 | north bend
# Processing Record 58 of Set 1 | georgetown
# Processing Record 59 of Set 1 | lebu
# Processing Record 60 of Set 1 | severo-yeniseyskiy
# Processing Record 61 of Set 1 | avrameni
# Missing data in city number 62 | Skipping inderborskiy
# Processing Record 63 of Set 1 | vinces
# Processing Record 64 of Set 1 | brigham city
# Processing Record 65 of Set 1 | ribeira grande
# Processing Record 66 of Set 1 | jacareacanga
# Processing Record 67 of Set 1 | muros
# Processing Record 68 of Set 1 | mnogovershinnyy
# Processing Record 69 of Set 1 | kaitangata
# Processing Record 70 of Set 1 | tuktoyaktuk
# Missing data in city number 71 | Skipping paucartambo
# Processing Record 72 of Set 1 | jamestown
# Missing data in city number 73 | Skipping amderma
# Missing data in city number 74 | Skipping asayita
# Processing Record 75 of Set 1 | carnarvon
# Missing data in city number 76 | Skipping navabad
# Processing Record 77 of Set 1 | opuwo
# Processing Record 78 of Set 1 | santa cruz
# Processing Record 79 of Set 1 | lompoc
# Processing Record 80 of Set 1 | saint anthony
# Processing Record 81 of Set 1 | poum
# Processing Record 82 of Set 1 | tenenkou
# Processing Record 83 of Set 1 | pimentel
# Processing Record 84 of Set 1 | moussoro
# Processing Record 85 of Set 1 | yurla
# Processing Record 86 of Set 1 | avarua
# Processing Record 87 of Set 1 | dikson
# Processing Record 88 of Set 1 | kapaa
# Processing Record 89 of Set 1 | ketchikan
# Processing Record 90 of Set 1 | barmer
# Processing Record 91 of Set 1 | ust-omchug
# Processing Record 92 of Set 1 | atuona
# Processing Record 93 of Set 1 | bredasdorp
# Processing Record 94 of Set 1 | kahului
# Processing Record 95 of Set 1 | aloleng
# Missing data in city number 96 | Skipping haibowan
# Processing Record 97 of Set 1 | sao lourenco da mata
# Missing data in city number 98 | Skipping sentyabrskiy
# Processing Record 99 of Set 1 | cherskiy
# Processing Record 100 of Set 1 | wazirabad
# Processing Record 101 of Set 1 | port alfred
# Processing Record 102 of Set 1 | butaritari
# Processing Record 103 of Set 1 | pujehun
# Processing Record 104 of Set 1 | east london
# Processing Record 105 of Set 1 | castro
# Processing Record 106 of Set 1 | alice springs
# Processing Record 107 of Set 1 | hobart
# Processing Record 108 of Set 1 | eau claire
# Processing Record 109 of Set 1 | butte
# Processing Record 110 of Set 1 | waiouru
# Processing Record 111 of Set 1 | skjervoy
# Processing Record 112 of Set 1 | ilulissat
# Processing Record 113 of Set 1 | torbay
# Processing Record 114 of Set 1 | thompson
# Processing Record 115 of Set 1 | saint-philippe
# Processing Record 116 of Set 1 | solnechnyy
# Processing Record 117 of Set 1 | fortuna
# Processing Record 118 of Set 1 | homa bay
# Processing Record 119 of Set 1 | sao filipe
# Processing Record 120 of Set 1 | mar del plata
# Processing Record 121 of Set 1 | talaya
# Processing Record 122 of Set 1 | camacha
# Processing Record 123 of Set 1 | buala
# Processing Record 124 of Set 1 | kingsport
# Processing Record 125 of Set 1 | nagua
# Processing Record 126 of Set 1 | husavik
# Missing data in city number 127 | Skipping barentsburg
# Processing Record 128 of Set 1 | ashoknagar
# Processing Record 129 of Set 1 | portland
# Processing Record 130 of Set 1 | san cristobal
# Processing Record 131 of Set 1 | cogon
# Processing Record 132 of Set 1 | naryan-mar
# Processing Record 133 of Set 1 | sitka
# Processing Record 134 of Set 1 | belaya gora
# Processing Record 135 of Set 1 | shingu
# Processing Record 136 of Set 1 | maningrida
# Processing Record 137 of Set 1 | provost
# Processing Record 138 of Set 1 | bandarbeyla
# Processing Record 139 of Set 1 | ayan
# Processing Record 140 of Set 1 | dunedin
# Processing Record 141 of Set 1 | khandyga
# Processing Record 142 of Set 1 | kyaukse
# Processing Record 143 of Set 1 | guerrero negro
# Processing Record 144 of Set 1 | geraldton
# Processing Record 145 of Set 1 | luderitz
# Processing Record 146 of Set 1 | alofi
# Processing Record 147 of Set 1 | port hardy
# Processing Record 148 of Set 1 | upernavik
# Processing Record 149 of Set 1 | barrow
# Processing Record 150 of Set 1 | wanganui
# Processing Record 151 of Set 1 | giddalur
# Processing Record 152 of Set 1 | tarabha
# Processing Record 153 of Set 1 | yellowknife
# Missing data in city number 154 | Skipping kracheh
# Processing Record 155 of Set 1 | tasiilaq
# Processing Record 156 of Set 1 | vila velha
# Processing Record 157 of Set 1 | kodiak
# Processing Record 158 of Set 1 | severo-kurilsk
# Processing Record 159 of Set 1 | kavaratti
# Processing Record 160 of Set 1 | yar-sale
# Processing Record 161 of Set 1 | dharchula
# Processing Record 162 of Set 1 | vrangel
# Processing Record 163 of Set 1 | sorland
# Processing Record 164 of Set 1 | hithadhoo
# Processing Record 165 of Set 1 | mackay
# Processing Record 166 of Set 1 | abu kamal
# Processing Record 167 of Set 1 | evensk
# Processing Record 168 of Set 1 | chokurdakh
# Processing Record 169 of Set 1 | lorengau
# Processing Record 170 of Set 1 | beroroha
# Processing Record 171 of Set 1 | coihaique
# Processing Record 172 of Set 1 | dwarka
# Processing Record 173 of Set 1 | souillac
# Processing Record 174 of Set 1 | mahebourg
# Processing Record 175 of Set 1 | valley
# Processing Record 176 of Set 1 | mandalgovi
# Processing Record 177 of Set 1 | kalianget
# Processing Record 178 of Set 1 | viru
# Processing Record 179 of Set 1 | sibanicu
# Processing Record 180 of Set 1 | nara
# Processing Record 181 of Set 1 | tura
# Processing Record 182 of Set 1 | nyurba
# Processing Record 183 of Set 1 | longyearbyen
# Processing Record 184 of Set 1 | ponta do sol
# Missing data in city number 185 | Skipping tsihombe
# Processing Record 186 of Set 1 | maniitsoq
# Processing Record 187 of Set 1 | eresos
# Processing Record 188 of Set 1 | ternate
# Processing Record 189 of Set 1 | hasaki
# Processing Record 190 of Set 1 | honiara
# Processing Record 191 of Set 1 | grand-santi
# Processing Record 192 of Set 1 | pangnirtung
# Processing Record 193 of Set 1 | faanui
# Processing Record 194 of Set 1 | norman wells
# Processing Record 195 of Set 1 | saint-augustin
# Missing data in city number 196 | Skipping attawapiskat
# Processing Record 197 of Set 1 | dembi dolo
# Processing Record 198 of Set 1 | airai
# Processing Record 199 of Set 1 | opotiki
# Processing Record 200 of Set 1 | berlevag
# Processing Record 201 of Set 1 | olafsvik
# Processing Record 202 of Set 1 | gympie
# Processing Record 203 of Set 1 | kalabo
# Processing Record 204 of Set 1 | iqaluit
# Processing Record 205 of Set 1 | ust-kulom
# Processing Record 206 of Set 1 | coquimbo
# Processing Record 207 of Set 1 | altamont
# Processing Record 208 of Set 1 | ngunguru
# Processing Record 209 of Set 1 | lake havasu city
# Processing Record 210 of Set 1 | tiksi
# Processing Record 211 of Set 1 | ulaangom
# Missing data in city number 212 | Skipping bid
# Processing Record 213 of Set 1 | broken hill
# Processing Record 214 of Set 1 | yuzhou
# Processing Record 215 of Set 1 | sainte-thecle
# Missing data in city number 216 | Skipping vaitupu
# Processing Record 217 of Set 1 | vao
# Processing Record 218 of Set 1 | fallon
# Processing Record 219 of Set 1 | esperance
# Processing Record 220 of Set 1 | lazaro cardenas
# Processing Record 221 of Set 1 | udachnyy
# Processing Record 222 of Set 1 | nanortalik
# Processing Record 223 of Set 1 | liaqatabad
# Processing Record 224 of Set 1 | sisimiut
# Processing Record 225 of Set 1 | jiuquan
# Processing Record 226 of Set 1 | srednekolymsk
# Processing Record 227 of Set 1 | port shepstone
# Processing Record 228 of Set 1 | salalah
# Processing Record 229 of Set 1 | lavrentiya
# Processing Record 230 of Set 1 | mago
# Processing Record 231 of Set 1 | caravelas
# Processing Record 232 of Set 1 | saskylakh
# Processing Record 233 of Set 1 | khatanga
# Processing Record 234 of Set 1 | kruisfontein
# Processing Record 235 of Set 1 | cidreira
# Processing Record 236 of Set 1 | cayenne
# Processing Record 237 of Set 1 | kloulklubed
# Processing Record 238 of Set 1 | ambulu
# Processing Record 239 of Set 1 | svetlaya
# Processing Record 240 of Set 1 | namibe
# Processing Record 241 of Set 1 | porto walter
# Processing Record 242 of Set 1 | phek
# Processing Record 243 of Set 1 | douentza
# Processing Record 244 of Set 1 | ostrovnoy
# Processing Record 245 of Set 1 | toora-khem
# Missing data in city number 246 | Skipping jiddah
# Processing Record 247 of Set 1 | hobyo
# Missing data in city number 248 | Skipping belushya guba
# Processing Record 249 of Set 1 | poronaysk
# Processing Record 250 of Set 1 | boali
# Processing Record 251 of Set 1 | avera
# Missing data in city number 252 | Skipping saleaula
# Processing Record 253 of Set 1 | wete
# Processing Record 254 of Set 1 | rio grande
# Processing Record 255 of Set 1 | pryazha
# Processing Record 256 of Set 1 | kuytun
# Processing Record 257 of Set 1 | los llanos de aridane
# Processing Record 258 of Set 1 | erzin
# Processing Record 259 of Set 1 | kavieng
# Processing Record 260 of Set 1 | new milford
# Processing Record 261 of Set 1 | tolaga bay
# Processing Record 262 of Set 1 | ballina
# Processing Record 263 of Set 1 | kamakwie
# Processing Record 264 of Set 1 | labuhan
# Processing Record 265 of Set 1 | otavi
# Processing Record 266 of Set 1 | gornyy
# Processing Record 267 of Set 1 | kosa
# Processing Record 268 of Set 1 | sovetskaya gavan
# Processing Record 269 of Set 1 | davila
# Processing Record 270 of Set 1 | puerto cabezas
# Processing Record 271 of Set 1 | le port
# Missing data in city number 272 | Skipping grand river south east
# Processing Record 273 of Set 1 | brae
# Processing Record 274 of Set 1 | nome
# Processing Record 275 of Set 1 | san jose
# Processing Record 276 of Set 1 | pontianak
# Missing data in city number 277 | Skipping yingshang
# Processing Record 278 of Set 1 | isugod
# Processing Record 279 of Set 1 | wanaka
# Processing Record 280 of Set 1 | grants pass
# Missing data in city number 281 | Skipping khonuu
# Processing Record 282 of Set 1 | northam
# Missing data in city number 283 | Skipping satitoa
# Processing Record 284 of Set 1 | chapais
# Processing Record 285 of Set 1 | benghazi
# Processing Record 286 of Set 1 | sakakah
# Processing Record 287 of Set 1 | vardo
# Missing data in city number 288 | Skipping warqla
# Missing data in city number 289 | Skipping yuzhno-yeniseyskiy
# Processing Record 290 of Set 1 | ixtapa
# Processing Record 291 of Set 1 | terrasini
# Processing Record 292 of Set 1 | songjianghe
# Processing Record 293 of Set 1 | livramento
# Missing data in city number 294 | Skipping mergui
# Processing Record 295 of Set 1 | korem
# Processing Record 296 of Set 1 | tuatapere
# Processing Record 297 of Set 1 | bambous virieux
# Processing Record 298 of Set 1 | hambantota
# Processing Record 299 of Set 1 | oruro
# Processing Record 300 of Set 1 | nizwa
# Processing Record 301 of Set 1 | codrington
# Processing Record 302 of Set 1 | athabasca
# Processing Record 303 of Set 1 | klaksvik
# Processing Record 304 of Set 1 | tautira
# Processing Record 305 of Set 1 | hinatuan
# Processing Record 306 of Set 1 | inirida
# Missing data in city number 307 | Skipping ye
# Processing Record 308 of Set 1 | adrar
# Processing Record 309 of Set 1 | uarini
# Processing Record 310 of Set 1 | la ronge
# Processing Record 311 of Set 1 | luanda
# Processing Record 312 of Set 1 | inhambane
# Processing Record 313 of Set 1 | poros
# Processing Record 314 of Set 1 | pahrump
# Missing data in city number 315 | Skipping mys shmidta
# Missing data in city number 316 | Skipping galiwinku
# Processing Record 317 of Set 1 | bardiyah
# Processing Record 318 of Set 1 | cadillac
# Processing Record 319 of Set 1 | ouargaye
# Processing Record 320 of Set 1 | port hawkesbury
# Processing Record 321 of Set 1 | winnemucca
# Processing Record 322 of Set 1 | colac
# Processing Record 323 of Set 1 | bubaque
# Processing Record 324 of Set 1 | seymchan
# Processing Record 325 of Set 1 | gelemso
# Processing Record 326 of Set 1 | ishigaki
# Processing Record 327 of Set 1 | halmasd
# Processing Record 328 of Set 1 | lamu
# Processing Record 329 of Set 1 | gatton
# Processing Record 330 of Set 1 | udimskiy
# Processing Record 331 of Set 1 | paamiut
# Processing Record 332 of Set 1 | tambopata
# Processing Record 333 of Set 1 | bahawalpur
# Processing Record 334 of Set 1 | bereda
# Processing Record 335 of Set 1 | banjar
# Processing Record 336 of Set 1 | college
# Processing Record 337 of Set 1 | port lincoln
# Missing data in city number 338 | Skipping umzimvubu
# Processing Record 339 of Set 1 | dongying
# Processing Record 340 of Set 1 | farmington
# Processing Record 341 of Set 1 | andenes
# Processing Record 342 of Set 1 | nata
# Processing Record 343 of Set 1 | grindavik
# Processing Record 344 of Set 1 | wajima
# Processing Record 345 of Set 1 | williams lake
# Processing Record 346 of Set 1 | lasa
# Processing Record 347 of Set 1 | kapoeta
# Processing Record 348 of Set 1 | goba
# Processing Record 349 of Set 1 | jeremie
# Missing data in city number 350 | Skipping rungata
# Processing Record 351 of Set 1 | atar
# Processing Record 352 of Set 1 | jalu
# Processing Record 353 of Set 1 | kamina
# Processing Record 354 of Set 1 | carauari
# Processing Record 355 of Set 1 | miri
# Processing Record 356 of Set 1 | launceston
# Processing Record 357 of Set 1 | nakhon thai
# Processing Record 358 of Set 1 | altus
# Processing Record 359 of Set 1 | lady frere
# Processing Record 360 of Set 1 | moba
# Processing Record 361 of Set 1 | muzhi
# Processing Record 362 of Set 1 | oistins
# Processing Record 363 of Set 1 | baracoa
# Processing Record 364 of Set 1 | nemuro
# Processing Record 365 of Set 1 | fort nelson
# Processing Record 366 of Set 1 | edd
# Processing Record 367 of Set 1 | itaituba
# Processing Record 368 of Set 1 | namatanai
# Processing Record 369 of Set 1 | mehamn
# Missing data in city number 370 | Skipping burica
# Processing Record 371 of Set 1 | atambua
# Processing Record 372 of Set 1 | capelinha
# Processing Record 373 of Set 1 | businga
# Processing Record 374 of Set 1 | san isidro
# Missing data in city number 375 | Skipping kuche
# Processing Record 376 of Set 1 | luganville
# Processing Record 377 of Set 1 | fare
# Processing Record 378 of Set 1 | khasan
# Processing Record 379 of Set 1 | rudnogorsk
# Processing Record 380 of Set 1 | mizdah
# Processing Record 381 of Set 1 | homer
# Processing Record 382 of Set 1 | bonthe
# Processing Record 383 of Set 1 | pemberton
# Processing Record 384 of Set 1 | havelock
# Processing Record 385 of Set 1 | tucuman
# Processing Record 386 of Set 1 | rock sound
# Processing Record 387 of Set 1 | beloha
# Processing Record 388 of Set 1 | frankfort
# Processing Record 389 of Set 1 | yishui
# Processing Record 390 of Set 1 | kamenka
# Processing Record 391 of Set 1 | ambon
# Processing Record 392 of Set 1 | wewak
# Processing Record 393 of Set 1 | ormara
# Processing Record 394 of Set 1 | nadvoitsy
# Processing Record 395 of Set 1 | ola
# Processing Record 396 of Set 1 | yerbogachen
# Processing Record 397 of Set 1 | tual
# Processing Record 398 of Set 1 | nhulunbuy
# Processing Record 399 of Set 1 | vigrestad
# Processing Record 400 of Set 1 | tomatlan
# Processing Record 401 of Set 1 | flinders
# Processing Record 402 of Set 1 | mangai
# Processing Record 403 of Set 1 | waipawa
# Missing data in city number 404 | Skipping palabuhanratu
# Processing Record 405 of Set 1 | taoudenni
# Processing Record 406 of Set 1 | jimeta
# Missing data in city number 407 | Skipping mocambique
# Processing Record 408 of Set 1 | shenjiamen
# Processing Record 409 of Set 1 | ribas do rio pardo
# Processing Record 410 of Set 1 | amloh
# Processing Record 411 of Set 1 | lata
# Processing Record 412 of Set 1 | lokosovo
# Processing Record 413 of Set 1 | khash
# Processing Record 414 of Set 1 | isangel
# Processing Record 415 of Set 1 | porto novo
# Processing Record 416 of Set 1 | victoria
# Processing Record 417 of Set 1 | itoman
# Processing Record 418 of Set 1 | walvis bay
# Processing Record 419 of Set 1 | sundumbili
# Processing Record 420 of Set 1 | thinadhoo
# Processing Record 421 of Set 1 | camana
# Processing Record 422 of Set 1 | mokrousovo
# Processing Record 423 of Set 1 | kez
# Processing Record 424 of Set 1 | surt
# Processing Record 425 of Set 1 | ancud
# Processing Record 426 of Set 1 | mount gambier
# Processing Record 427 of Set 1 | yabelo
# Processing Record 428 of Set 1 | champerico
# Processing Record 429 of Set 1 | weinan
# Missing data in city number 430 | Skipping mutsamudu
# Processing Record 431 of Set 1 | kununurra
# Processing Record 432 of Set 1 | moose factory
# Missing data in city number 433 | Skipping dinsor
# Processing Record 434 of Set 1 | manjakandriana
# Processing Record 435 of Set 1 | mtimbira
# Missing data in city number 436 | Skipping buariki
# Processing Record 437 of Set 1 | manbij
# Missing data in city number 438 | Skipping kadykchan
# Missing data in city number 439 | Skipping ningan
# Processing Record 440 of Set 1 | laguna
# Processing Record 441 of Set 1 | touros
# Processing Record 442 of Set 1 | sumenep
# Processing Record 443 of Set 1 | te anau
# Processing Record 444 of Set 1 | dondo
# Processing Record 445 of Set 1 | birjand
# Processing Record 446 of Set 1 | baykit
# Processing Record 447 of Set 1 | yazman
# Processing Record 448 of Set 1 | emporia
# Processing Record 449 of Set 1 | haines junction
# Processing Record 450 of Set 1 | chuguyevka
# Missing data in city number 451 | Skipping bargal
# Processing Record 452 of Set 1 | washougal
# Processing Record 453 of Set 1 | quelimane
# Missing data in city number 454 | Skipping hunza
# Processing Record 455 of Set 1 | skelleftea
# Missing data in city number 456 | Skipping dzhusaly
# Processing Record 457 of Set 1 | waddan
# Processing Record 458 of Set 1 | saquena
# Processing Record 459 of Set 1 | moerai
# Processing Record 460 of Set 1 | dalvik
# Missing data in city number 461 | Skipping dujuma
# Processing Record 462 of Set 1 | eyl
# Processing Record 463 of Set 1 | constantine
# Processing Record 464 of Set 1 | fukue
# Processing Record 465 of Set 1 | acurenam
# Processing Record 466 of Set 1 | nishihara
# Processing Record 467 of Set 1 | chandauli
# Processing Record 468 of Set 1 | matara
# Processing Record 469 of Set 1 | beringovskiy
# Processing Record 470 of Set 1 | halifax
# Processing Record 471 of Set 1 | anloga
# Processing Record 472 of Set 1 | kitimat
# Processing Record 473 of Set 1 | iskateley
# Processing Record 474 of Set 1 | andradas
# Processing Record 475 of Set 1 | bengkulu
# Processing Record 476 of Set 1 | waingapu
# Processing Record 477 of Set 1 | abu samrah
# Processing Record 478 of Set 1 | leshukonskoye
# Missing data in city number 479 | Skipping chagda
# Processing Record 480 of Set 1 | vanimo
# Processing Record 481 of Set 1 | mayo
# Processing Record 482 of Set 1 | san patricio
# Processing Record 483 of Set 1 | anadyr
# Processing Record 484 of Set 1 | aklavik
# Processing Record 485 of Set 1 | izhma
# Processing Record 486 of Set 1 | kawalu
# Processing Record 487 of Set 1 | yamaga
# Processing Record 488 of Set 1 | voznesenye
# Processing Record 489 of Set 1 | sungaipenuh
# Processing Record 490 of Set 1 | tocopilla
# Processing Record 491 of Set 1 | ous
# Processing Record 492 of Set 1 | makakilo city
# Processing Record 493 of Set 1 | stanghelle
# Processing Record 494 of Set 1 | saldanha
# Processing Record 495 of Set 1 | batobato
# Processing Record 496 of Set 1 | kokemaki
# Processing Record 497 of Set 1 | yarada
# Processing Record 498 of Set 1 | nizhnevartovsk
# Processing Record 499 of Set 1 | port macquarie
# Processing Record 500 of Set 1 | paso de patria
# Missing data in city number 501 | Skipping artyk
# Processing Record 502 of Set 1 | hami
# Processing Record 503 of Set 1 | qaqortoq
# Processing Record 504 of Set 1 | lyngseidet
# Processing Record 505 of Set 1 | rawson
# Processing Record 506 of Set 1 | samarai
# Processing Record 507 of Set 1 | kutum
# Processing Record 508 of Set 1 | yasnyy
# Processing Record 509 of Set 1 | barra patuca
# Processing Record 510 of Set 1 | tobol
# Processing Record 511 of Set 1 | meulaboh
# Processing Record 512 of Set 1 | orlik
# Processing Record 513 of Set 1 | kijang
# Processing Record 514 of Set 1 | umm lajj
# Processing Record 515 of Set 1 | yichun
# Processing Record 516 of Set 1 | mercedes
# Processing Record 517 of Set 1 | stabat
# Processing Record 518 of Set 1 | sobolevo
# Processing Record 519 of Set 1 | itarema
# Processing Record 520 of Set 1 | bristol
# Processing Record 521 of Set 1 | aras
# Processing Record 522 of Set 1 | shurugwi
# Processing Record 523 of Set 1 | hualmay
# Processing Record 524 of Set 1 | flin flon
# Processing Record 525 of Set 1 | lima
# Processing Record 526 of Set 1 | sangar
# Processing Record 527 of Set 1 | sarkand
# Processing Record 528 of Set 1 | viedma
# Processing Record 529 of Set 1 | ust-nera
# Processing Record 530 of Set 1 | seoul
# Processing Record 531 of Set 1 | aldan
# Processing Record 532 of Set 1 | mount isa
# Processing Record 533 of Set 1 | tieling
# Processing Record 534 of Set 1 | san quintin
# Processing Record 535 of Set 1 | gberia fotombu
# Processing Record 536 of Set 1 | binabalian
# Processing Record 537 of Set 1 | gornopravdinsk
# Processing Record 538 of Set 1 | constitucion
# Processing Record 539 of Set 1 | alyangula
# Processing Record 540 of Set 1 | sarapul
# Processing Record 541 of Set 1 | westport
# Processing Record 542 of Set 1 | gashua
# Processing Record 543 of Set 1 | deputatskiy
# Processing Record 544 of Set 1 | agar
# Processing Record 545 of Set 1 | mantua
# Processing Record 546 of Set 1 | taltal
# Processing Record 547 of Set 1 | cockburn town
# Processing Record 548 of Set 1 | alekseyevsk
# Processing Record 549 of Set 1 | kutahya
# Processing Record 550 of Set 1 | windhoek
# Processing Record 551 of Set 1 | ostersund
# Processing Record 552 of Set 1 | bathsheba
# Missing data in city number 553 | Skipping kerki
# Processing Record 554 of Set 1 | tabas
# Processing Record 555 of Set 1 | changji
# Processing Record 556 of Set 1 | soeng sang
# Processing Record 557 of Set 1 | padampur
# Processing Record 558 of Set 1 | alexandria
# Processing Record 559 of Set 1 | tessalit
# Processing Record 560 of Set 1 | idrinskoye
# Processing Record 561 of Set 1 | eenhana
# Processing Record 562 of Set 1 | kyzyl-suu
# Processing Record 563 of Set 1 | zhob
# Processing Record 564 of Set 1 | ochakiv
# Processing Record 565 of Set 1 | buraydah
# Processing Record 566 of Set 1 | hay river
# Processing Record 567 of Set 1 | clinton
# Processing Record 568 of Set 1 | louth
# Processing Record 569 of Set 1 | ahome
# Processing Record 570 of Set 1 | saint-georges
# Missing data in city number 571 | Skipping malwan
# Processing Record 572 of Set 1 | kochinda
# Processing Record 573 of Set 1 | erenhot
# Processing Record 574 of Set 1 | manicore
# Missing data in city number 575 | Skipping grimari
# Processing Record 576 of Set 1 | peace river
# Processing Record 577 of Set 1 | maragogi
# Processing Record 578 of Set 1 | gat
# Processing Record 579 of Set 1 | luena
# Processing Record 580 of Set 1 | aguimes
# Processing Record 581 of Set 1 | bahir dar
# Processing Record 582 of Set 1 | la grande
# Processing Record 583 of Set 1 | mlonggo
# Processing Record 584 of Set 1 | bull savanna
# Processing Record 585 of Set 1 | lyubim
# Processing Record 586 of Set 1 | dongsheng
# Processing Record 587 of Set 1 | passo fundo
# Processing Record 588 of Set 1 | lakes entrance
# Processing Record 589 of Set 1 | mahajanga
# Processing Record 590 of Set 1 | kenora
# Processing Record 591 of Set 1 | akdepe
# Processing Record 592 of Set 1 | caracollo
# Missing data in city number 593 | Skipping cockburn harbour

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
length_City = {
     'City': len(city_name),
     'Cloudiness': len(Cloudiness),
     'Country': len(Country),
     'Date': len(Date),
     'Humidity': len(Humidity),
     'Lat': len(Lat),
     'Lng': len(Lng),
     'Max Temp': len(Max_Temp),
     'Wind Speed': len(Wind_Speed)
 }

length_City
# Out:
# {'City': 540,
#  'Cloudiness': 540,
#  'Country': 540,
#  'Date': 540,
#  'Humidity': 540,
#  'Lat': 540,
#  'Lng': 540,
#  'Max Temp': 540,
#  'Wind Speed': 540}

# %%
Weather_df = pd.DataFrame({
                        'City': city_name,
                        'Cloudiness': Cloudiness,
                        'Country': Country,
                        'Date': Date,
                        'Humidity': Humidity,
                        'Lat': Lat,
                        'Lng': Lng,
                        'Max Temp': Max_Temp,
                        'Wind Speed': Wind_Speed
                        })

pd.DataFrame.to_csv(Weather_df, 'city_data.csv')
Weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Quatre Cocos          40      MU  1579370506        88 -20.21   57.76
# 1    Half Moon Bay           1      US  1579370865        66  37.46 -122.43
# 2   Port Elizabeth          90      ZA  1579370659        72 -33.92   25.57
# 3           Dingle           0      PH  1579370438        89  11.00  122.67
# 4  Arraial do Cabo          75      BR  1579370328        61 -22.97  -42.03
#
#    Max Temp  Wind Speed
# 0     81.00        8.05
# 1     50.00        5.82
# 2     66.20        8.05
# 3     74.28        8.05
# 4     80.60        9.17

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Max Temp']
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Max Temperature ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Humidity'] 
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Humidity ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Cloudiness']
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Cloudiness ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_value = Weather_df['Lat']
y_value = Weather_df['Wind Speed']
plt.scatter(x_value, y_value, edgecolors='black', marker='o', color='blue')

weather_dt = datetime.fromtimestamp(Weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"City Latitude vs. Wind Speed ({weather_dt})")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def regression(X_value, Y_value, X_lable, Y_lable):
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(X_value, Y_value)
    regress_value = X_value * slope + intercept
    
    line_eq = f" y= {round(slope,2)}x + {round(intercept,2)}"
    
    plt.annotate(line_eq, (20, 15), fontsize=15, color='red')
    plt.scatter(X_value, Y_value, marker='o', color='blue')
    plt.title(f"City Latitude vs. Wind Speed ({weather_dt})")
    plt.grid()
    plt.xlabel(X_lable)
    plt.ylabel(Y_lable)
    print(f"The r-squared is: {rvalue}")

    plt.plot(X_value, regress_value, 'r-')
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_df = Weather_df.loc[Weather_df['Lng']>=0]
Southern_df = Weather_df.loc[Weather_df['Lng']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = Northern_df['Lat']
y_value = Northern_df['Max Temp']
X_lable = 'Latitude'
Y_lable = 'Max Temp'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.7859348852450807

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = Southern_df['Max Temp']
y_value = Southern_df['Lat']
X_lable = 'Latitude'
Y_lable = 'Max Temp'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.7835454506688448

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = Northern_df['Max Temp']
y_value = Northern_df['Lat']
X_lable = 'Latitude'
Y_lable = 'Max Temp'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.7859348852450807

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = Southern_df['Lat']
y_value = Southern_df['Humidity']
X_lable = 'Latitude'
Y_lable = 'Humidity'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.28796940562528156

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = Northern_df['Lat']
y_value = Northern_df['Cloudiness']
X_lable = 'Latitude'
Y_lable = 'Cloudiness'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.11769093837181802

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = Southern_df['Lat']
y_value = Southern_df['Cloudiness']
X_lable = 'Latitude'
Y_lable = 'Cloudiness'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.07056083337986668

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = Northern_df['Lat']
y_value = Northern_df['Wind Speed']
X_lable = 'Latitude'
Y_lable = 'Wind Speed'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: 0.004422965655373455

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = Southern_df['Lat']
y_value = Southern_df['Wind Speed']
X_lable = 'Latitude'
Y_lable = 'Wind Speed'
regression( x_value, y_value, X_lable, Y_lable)
# Out:
# The r-squared is: -0.028119337685595602
